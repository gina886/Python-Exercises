# %%
import pandas as pd

df = pd.read_csv("/Users/gina/Desktop/successful_educations.csv") # open and read data
print(df.head(2))# read 2rows

print(df.tail(2))

print(df.info())# 108 rows / 10 columns / different data type of the each column

pf = df[df['Degree'] == 'PhD'] # read phd 
print(pf)

print(df.groupby('Degree').size())
# Out:
#          Name    Profession               Degree                Field  \
# 0   Elon Musk  Entrepreneur  Bachelor of Science  Physics & Economics
# 1  Bill Gates  Entrepreneur          Dropped Out     computer science
#
#                   Institution  Graduation Year Country  \
# 0  University of Pennsylvania           1997.0     USA
# 1          Harvard University           1975.0     USA
#
#   University Global Ranking GPA (or Equivalent) Scholarship/Award
# 0                        13                 3.7       Dean’s List
# 1                         5                 NaN       Dean’s List
#                  Name Profession    Degree      Field  \
# 106   Susanne Klatten   Business  Bachelor  Economics
# 107  Cyrus Poonawalla   Business  Bachelor   Pharmacy
#
#                         Institution  Graduation Year  Country  \
# 106  Technical University of Munich           1993.0  Germany
# 107              University of Pune           1966.0    India
#
# ...
